# %% [markdown]
# #About Dataset:
#
# The market research team at AdRight is assigned the task to identify the profile of the typical customer for each treadmill product offered by CardioGood Fitness. The market research team decides to investigate whether there are differences across the product lines with respect to customer characteristics. The team decides to collect data on individuals who purchased a treadmill at a CardioGoodFitness retail store during the prior three months. The data are stored in the CardioGoodFitness.csv file.
#
#
# The team identifies the following customer variables to study:
#
#  - product purchased, TM195, TM498, or TM798;
#  - gender;
#  - age, in years;
#  - education, in years;
#  - relationship status, single or partnered;
#  - annual household income ($);
#  - average number of times the customer plans to use the treadmill each week;
#  - average number of miles the customer expects to walk/run each week;
#  - and self-rated fitness on an 1-to-5 scale, where 1 is poor shape and 5 is excellent shape.
#
# ###Perform descriptive analytics to create a customer profile for each CardioGood Fitness treadmill product line.

# %% [markdown]
# ##Dataset Information :
# ###cardiogoodfitness.csv: The csv contains data related to customers who have purchased different model from Cardio Good Fitness :
# -	Product - the model no. of the treadmill
# -	Age - in no of years, of the customer
# -	Gender - of the customer
# -	Education - in no. of years, of the customer
# -	Marital Status - of the customer
# -	Usage - Avg. # times the customer wants to use the treadmill every week
# -	Fitness - Self rated fitness score of the customer (5 - very fit, 1 - very unfit)
# -	Income - of the customer
# -	Miles- expected to run
# ###Objective
# -	Come up with a customer profile (characteristics of a customer) of the different products
# -	Based on the data we have to generate a set of insights and recommendations that will help the company in targetting new customers

# %% [markdown]
# ### Use EDA to answer following:
#
# - How many models does store have?
# - Which is most sold Model?
# - Are Male customers buying treadmill more than female customers?
# - What is the Income ,Age , Education of people buying treadmill.?
# - What is the self rated fitness of customers buying treadmill.?
# - Are married customer buying Treadmill more than Single customers?
# - Is there any relation between Income and model.?
# - Is there any relation between Age and model ?
# - Is there any relation between self rated fitness and model .?
# - Is there any relation between education and model.?
# - Does gender has any effect on model customer buy .?
# - Does Martial status has any effect model customer buy.?
# - Is there different age groups buying different models.?
# - Relation between Age, Income and education and model bought ?

# %% [markdown]
# # **Step 1 : - Data Inspection**

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
Data  = pd.read_csv('/content/drive/MyDrive/Data_m/EDA DATA/CardioGoodFitness.csv')

# %%
Data.head()
# Out:
#   Product  Age  Gender  Education MaritalStatus  Usage  Fitness  Income  Miles
# 0   TM195   18    Male         14        Single      3        4   29562    112
# 1   TM195   19    Male         15        Single      2        3   31836     75
# 2   TM195   19  Female         14     Partnered      4        3   30699     66
# 3   TM195   19    Male         12        Single      3        3   32973     85
# 4   TM195   20    Male         13     Partnered      4        2   35247     47

# %%
Data.tail()
# Out:
#     Product  Age Gender  Education MaritalStatus  Usage  Fitness  Income  \
# 175   TM798   40   Male         21        Single      6        5   83416
# 176   TM798   42   Male         18        Single      5        4   89641
# 177   TM798   45   Male         16        Single      5        5   90886
# 178   TM798   47   Male         18     Partnered      4        5  104581
# 179   TM798   48   Male         18     Partnered      4        5   95508
#
#      Miles
# 175    200
# 176    200
# 177    160
# 178    120
# 179    180

# %%
Data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 180 entries, 0 to 179
# Data columns (total 9 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Product        180 non-null    object
#  1   Age            180 non-null    int64
#  2   Gender         180 non-null    object
#  3   Education      180 non-null    int64
#  4   MaritalStatus  180 non-null    object
#  5   Usage          180 non-null    int64
#  6   Fitness        180 non-null    int64
#  7   Income         180 non-null    int64
#  8   Miles          180 non-null    int64
# dtypes: int64(6), object(3)
# memory usage: 12.8+ KB

# %%
Data.shape
# Out:
# (180, 9)

# %%
# Data.describe(include='all')  to apply include='all' to print all the values of dataset
Data.describe()
# Out:
#               Age   Education       Usage     Fitness         Income  \
# count  180.000000  180.000000  180.000000  180.000000     180.000000
# mean    28.788889   15.572222    3.455556    3.311111   53719.577778
# std      6.943498    1.617055    1.084797    0.958869   16506.684226
# min     18.000000   12.000000    2.000000    1.000000   29562.000000
# 25%     24.000000   14.000000    3.000000    3.000000   44058.750000
# 50%     26.000000   16.000000    3.000000    3.000000   50596.500000
# 75%     33.000000   16.000000    4.000000    4.000000   58668.000000
# max     50.000000   21.000000    7.000000    5.000000  104581.000000
#
#             Miles
# count  180.000000
# mean   103.194444
# std     51.863605
# min     21.000000
# 25%     66.000000
# 50%     94.000000
# 75%    114.750000
# max    360.000000

# %% [markdown]
# # **STEP 2 :- DATA CLEANNING**

# %%
# Data Cleanning

# %%
# check for missing data
Data.isnull().sum()
# Out:
# Product          0
# Age              0
# Gender           0
# Education        0
# MaritalStatus    0
# Usage            0
# Fitness          0
# Income           0
# Miles            0
# dtype: int64

# %%
# there are no missing null value of data set

# %%
Data.duplicated().sum()
# Out:
# np.int64(0)

# %%
# There are no duplicate value in the dataset

# %% [markdown]
# # **Step 3: Univariate Analysis**

# %%
# Numerical Columns
sns.histplot(data=Data, x ='Age', kde=True)
# Out:
# <Axes: xlabel='Age', ylabel='Count'>

# %%
sns.boxplot(data=Data, x ="Age")
# Out:
# <Axes: xlabel='Age'>

# %%
sns.boxplot(data=Data, y ="Age")
# Out:
# <Axes: ylabel='Age'>

# %%
Data['Age'].describe()
# Out:
# count    180.000000
# mean      28.788889
# std        6.943498
# min       18.000000
# 25%       24.000000
# 50%       26.000000
# 75%       33.000000
# max       50.000000
# Name: Age, dtype: float64

# %%
#  observation

#  Average age of customers buying treadmill is 28.7
#  youngest customers are 18 yrs old and oldest customer are 50 years old
#  most of the customers are in the range of 23 -33

# %%
# Income Analysis

# %%
sns.histplot(data=Data, x ="Income")
# Out:
# <Axes: xlabel='Income', ylabel='Count'>

# %%
sns.boxplot(data=Data, x ="Income")
# Out:
# <Axes: xlabel='Income'>

# %%
Data["Income"].describe()
# Out:
# count       180.000000
# mean      53719.577778
# std       16506.684226
# min       29562.000000
# 25%       44058.750000
# 50%       50596.500000
# 75%       58668.000000
# max      104581.000000
# Name: Income, dtype: float64

# %%
# #Observation
# # Most of the customer earn between 40 to 60k
#   Average salary of category of customer is 53k , max is 100k , min is 29k
#   there are outliers in the data above 78k

# %%
sns.histplot(data=Data, x ="Miles", kde= True)
# Out:
# <Axes: xlabel='Miles', ylabel='Count'>

# %%
sns.boxplot(data=Data, x ="Miles")
# Out:
# <Axes: xlabel='Miles'>

# %%
Data['Miles'].describe()
# Out:
# count    180.000000
# mean     103.194444
# std       51.863605
# min       21.000000
# 25%       66.000000
# 50%       94.000000
# 75%      114.750000
# max      360.000000
# Name: Miles, dtype: float64

# %%
# Observation
#  there are outliers above 100 Miles
#  on an average customers plan to run 50 - 120 miles per week

# %%
# Univariate Analysis of pd.Categorical columns|

# %%
# Product
sns.countplot(data=Data, x ="Product")
# Out:
# <Axes: xlabel='Product', ylabel='count'>

# %%
Data['Product'].value_counts(normalize=True)*100
# Out:
# Product
# TM195    44.444444
# TM498    33.333333
# TM798    22.222222
# Name: proportion, dtype: float64

# %%
Data.groupby('Product').size()
# Out:
# Product
# TM195    80
# TM498    60
# TM798    40
# dtype: int64

# %%
# from re import I
# Observation

# Tm195 is the most popular product amongst the customer , 44% customer.bought iternext
# next is TN498, 33% customers bought it
# TM798 is bought by 22% customers

# %%
sns.countplot(data=Data, x ="Gender")
# Out:
# <Axes: xlabel='Gender', ylabel='count'>

# %%
Data.Gender.value_counts(normalize=True)*100
# Out:
# Gender
# Male      57.777778
# Female    42.222222
# Name: proportion, dtype: float64

# %%
# #Observation
# most of the  customers are male are 60% and female are 40%

# %%
# Eduction Analysis

# %%
sns.countplot(data=Data, x ="Education")
# Out:
# <Axes: xlabel='Education', ylabel='count'>

# %%
Data.Education.value_counts(normalize=True)*100
# Out:
# Education
# 16    47.222222
# 14    30.555556
# 18    12.777778
# 15     2.777778
# 13     2.777778
# 12     1.666667
# 21     1.666667
# 20     0.555556
# Name: proportion, dtype: float64

# %%
# # Observation
# # 14 : 9th class
# # 15 : 10th
# # 20 :
# # 22 : Bachelors

# Most of the customer have eduction as year group are 14  16 & 18 , these are college going student

# %%
sns.countplot(data=Data, x ="MaritalStatus")
# Out:
# <Axes: xlabel='MaritalStatus', ylabel='count'>

# %%
Data.MaritalStatus.value_counts(normalize=True)*100
# Out:
# MaritalStatus
# Partnered    59.444444
# Single       40.555556
# Name: proportion, dtype: float64

# %%
# # Observation
# couples or partnered customers are more than single customers

# %%
sns.countplot(data=Data, x ="Usage")
# Out:
# <Axes: xlabel='Usage', ylabel='count'>

# %%
Data.Usage.value_counts(normalize=True)*100
# Out:
# Usage
# 3    38.333333
# 4    28.888889
# 2    18.333333
# 5     9.444444
# 6     3.888889
# 7     1.111111
# Name: proportion, dtype: float64

# %%
# observation

# most of the customer plan to use the treadmill 2 , 3 & 4 times

# %%
sns.countplot(data=Data, x ="Fitness")
# Out:
# <Axes: xlabel='Fitness', ylabel='count'>

# %%
Data.Fitness.value_counts(normalize=True)*100
# Out:
# Fitness
# 3    53.888889
# 5    17.222222
# 2    14.444444
# 4    13.333333
# 1     1.111111
# Name: proportion, dtype: float64

# %%
# most ofthe customer who bought product rated themseleve 3 on rating

# %% [markdown]
# # **STEP 4 :- Bivariate Analysis**

# %%
# Product and Age

# %%
sns.histplot(data=Data, x ="Age", hue="Product")
# Out:
# <Axes: xlabel='Age', ylabel='Count'>

# %%
# sns.distplot(data=Data, x ="Age", col="Product")
# sns.histplot(data=Data, x ="Age", col="Product")
sns.displot(data=Data, x ="Age", col="Product")

# %%
sns.boxplot(data=Data, y ="Age", hue ="Product")
# Out:
# <Axes: ylabel='Age'>

# %%
# Observations
#  TM195 is perfered by customers in age group 23 to 33
#  TM498 is perferred by customers in age group 24 to 34
#  TM798 is pereferred by customers in age group 25 and above pefferred by older ppl

# %%
# Product vs Gender

# %%
sns.countplot(data=Data, x ="Gender", hue="Product")
# Out:
# <Axes: xlabel='Gender', ylabel='count'>

# %%
#female cust are not preferring TM798

# %%
# Product vs Eduction

# %%
sns.countplot(data=Data, x ="Education", hue="Product")
# Out:
# <Axes: xlabel='Education', ylabel='count'>

# %%
# just another way to draw a plot
sns.countplot(data=Data, x ="Product", hue="Education")
# Out:
# <Axes: xlabel='Product', ylabel='count'>

# %%
# # TM798 is more popular amongst customer with 16 years and above eduction
# TM195 & TM498 are more popoular among customer with 16 year or less year of eduction

# %%
# Product Vs Miles

# %%
sns.boxplot(data=Data, x ="Product", y="Miles")
# Out:
# <Axes: xlabel='Product', ylabel='Miles'>

# %%
# Observation
# # - TM195 is preferred by younger customers, while TM798 appeals to older age groups.

# %% [markdown]
# Other Bivariate Analyse

# %%
# Income Vs Age
sns.scatterplot(data=Data, x ="Age", y="Income")
plt.title("Income Vs Age")
plt.show()

# %%
# Observation
# older customers earn more than younger customers

# %%
# MIles Vs Age
sns.scatterplot(data=Data, x ="Age", y="Miles")
plt.title("MIles Vs Age")
plt.show()

# %%
# observation
# Younger customer plan to run more miles per week

# %%
# Miles vs Income
sns.scatterplot(data=Data, x ="Income", y="Miles")
plt.title("MIles Vs Income")
plt.show()

# %%
Data.Income.value_counts(normalize=True)*100
# Out:
# Income
# 45480     7.777778
# 52302     5.000000
# 53439     4.444444
# 54576     4.444444
# 46617     4.444444
#             ...
# 85906     0.555556
# 99601     0.555556
# 103336    0.555556
# 95866     0.555556
# 95508     0.555556
# Name: proportion, Length: 62, dtype: float64

# %%
# Observation
# no strong correlation between income and miles

# %%
# Correlation Matrix
numerical_data = Data.select_dtypes(include=[np.number])
corr_matrix = numerical_data.corr()
sns.heatmap(corr_matrix, annot=True, cmap='coolwarm')
plt.title('Correlation Matrix')
plt.show()

# %%
# Observation:
# - Age and income are moderately correlated.
# - Miles has no strong correlation with other numerical variables.

# %% [markdown]
# # **Step 5 : MultiVariate Analysis**

# %%
# Pairplot for  numerical variables
sns.pairplot(Data, hue='Product')
plt.show()

# %%
# Observation:
# - TM798 stands out with customers having higher income and mileage.

# %%
# Observations:
# - The diagonal of the pairplot displays the KDE plots of individual variables (Age, Income, and Miles) for each product.
#
# - **Age Distribution (KDE plot along the diagonal)**:
#   - **TM195**: The distribution is slightly skewed to the younger age group, with most customers being in their 20s and 30s.
#   - **TM498**: The age distribution is more spread out, showing a broader range of ages, but still with a higher concentration in the 30-50 age range.
#   - **TM798**: This product's customers tend to be older, with the peak of the KDE shifted to the 40-60 age range.
#
# - **Income Distribution (KDE plot along the diagonal)**:
#   - **TM195**: The income distribution is more concentrated in the lower income brackets, with a peak around $40,000-$60,000.
#   - **TM498**: The income distribution is more spread, with a noticeable concentration around $60,000-$80,000.
#   - **TM798**: The income distribution shows a clear peak around the higher income bracket ($80,000+), indicating that TM798 appeals to wealthier customers.
#
# - **Miles Distribution (KDE plot along the diagonal)**:
#   - **TM195**: Customers generally plan to walk/run fewer miles, with a peak at lower values (< 30 miles).
#   - **TM498**: The distribution is more spread out, but still peaks at lower mileages, suggesting moderate use.
#   - **TM798**: Customers plan to use their treadmill significantly more, with a peak at higher mileage values (50+ miles), indicating heavier usage.
#
# - **Summary**:
#   - **TM798** customers generally have higher income, older age, and plan to run more miles.
#   - **TM195** customers are younger, have lower income, and plan to run fewer miles.
#   - **TM498** customers represent a middle ground in terms of income, age, and planned mileage.

# %% [markdown]
# Based on the insights from the dataset, the marketing team can derive several action items to refine their strategies and target the appropriate customer segments for each product. Here are some potential action items:
#
# ### 1. **Targeted Advertising and Messaging**:
#    - **For TM195**:
#      - Focus on younger customers with moderate incomes by highlighting affordability, value for money, and moderate mileage expectations.
#      - Emphasize product suitability for customers with a more casual fitness lifestyle (e.g., light to moderate treadmill use).
#      - Tailor marketing messages towards budget-conscious, younger individuals or families.
#
#    - **For TM498**:
#      - Position TM498 as a versatile product that appeals to a broad demographic, from moderate to high-income customers.
#      - Highlight its balance between cost and performance, catering to those looking for a mid-range treadmill that meets both fitness and budget goals.
#      - Target middle-income professionals and families seeking long-term value in a treadmill.
#
#    - **For TM798**:
#      - Focus on wealthier, older customers who plan to engage in more intense treadmill use.
#      - Highlight premium features such as durability, advanced technology, and high performance for serious fitness enthusiasts.
#      - Emphasize higher-mileage use and potential health benefits, positioning the product as ideal for older, fitness-conscious customers.
#      - Target affluent, middle-aged to senior customers through digital channels (e.g., LinkedIn, Facebook ads) and focus on showcasing the product’s premium attributes.
#
# ### 2. **Product Customization and Positioning**:
#    - **For TM195**:
#      - Introduce a product bundle or discount for younger buyers or those with moderate incomes (e.g., offering family-friendly plans or discounts for first-time buyers).
#      - Consider a version of TM195 with features specifically targeted at beginners or customers looking for lighter, less expensive options.
#
#    - **For TM498**:
#      - Position it as a "middle-ground" product, ideal for customers who want both value and quality without spending as much as on TM798.
#      - Develop marketing campaigns that emphasize product longevity, ease of use, and solid performance, targeting people looking for a reliable treadmill at a reasonable price.
#
#    - **For TM798**:
#      - Offer an upscale, premium experience with emphasis on the long-term value and durability of the treadmill.
#      - Explore collaboration with fitness influencers or specialists who appeal to the older demographic, focusing on fitness goals such as maintaining an active lifestyle into older age.
#
# ### 3. **Content Strategy**:
#    - **For TM195**:
#      - Develop content that resonates with younger audiences, such as social media campaigns and testimonials from young, budget-conscious users.
#      - Use blogs, influencer reviews, and video content to show how TM195 fits into the lifestyle of young professionals or families.
#
#    - **For TM498**:
#      - Use content that appeals to middle-income customers, including customer stories, testimonials from families or professionals, and product demonstrations.
#      - Provide educational content about the benefits of fitness and how TM498 supports a healthy lifestyle for all ages and fitness levels.
#
#    - **For TM798**:
#      - Develop premium content aimed at older, affluent users who prioritize health and fitness, such as articles on fitness for seniors, advanced treadmill features, and success stories from older users.
#      - Leverage high-quality video content to show the product in use by fitness enthusiasts, featuring testimonials from users with higher mileage goals.
#
# ### 4. **Promotions and Discounts**:
#    - **For TM195**:
#      - Offer discounts or loyalty programs targeted at younger customers (e.g., students or recent graduates).
#      - Provide seasonal promotions to appeal to customers who may be considering fitness resolutions (e.g., New Year, summer).
#
#    - **For TM498**:
#      - Introduce a loyalty program or a trade-in offer for customers looking to upgrade from older models or for repeat purchases from middle-income customers.
#      - Create bundled offers (e.g., treadmill + accessories) for customers looking to add value to their purchase.
#
#    - **For TM798**:
#      - Consider offering a premium service package (e.g., extended warranty, personalized fitness coaching) as part of the sales pitch to attract high-income customers.
#      - Launch limited-time offers or exclusive perks for customers who have shown interest in high-end fitness products.
#
# ### 5. **Market Segmentation and Personalization**:
#    - **For all products**:
#      - Use data to personalize marketing messages, highlighting specific benefits based on customer demographics (age, income, education).
#      - Segment customers based on their expected mileage and fitness goals (e.g., light use vs. heavy use) to tailor product recommendations.
#      - Consider geographic segmentation as well, where certain regions may have a higher concentration of specific age or income groups.
#
# ### 6. **Engagement with Education and Income Insights**:
#    - **For TM798**:
#      - Engage with higher education institutions or senior fitness programs to directly market the product to educated, older individuals who may value the advanced features and health benefits.
#      - Collaborate with educational platforms that focus on healthy aging or senior fitness programs, offering discounts or collaborations.
#
# ### 7. **Customer Feedback and Improvement**:
#    - **For all products**:
#      - Regularly collect customer feedback to improve marketing strategies and product offerings, especially focusing on customer satisfaction across different age groups and income levels.
#      - Identify potential areas for product improvements based on specific demographic preferences (e.g., features for younger vs. older users).
#
# By translating these insights into concrete action items, the marketing team can more effectively target potential customers, enhance engagement with the right audience, and ultimately drive sales for each product segment.

# %%
def dist_box(data):
    # Function plots a combined graph for univariate analysis of continuous variable
    # to check spread, central tendency, dispersion, and outliers
    Name = data.name.upper()
    fig, axes = plt.subplots(1, 2, figsize=(17, 7))
    fig.suptitle("SPREAD OF DATA FOR " + Name, fontsize=18, fontweight='bold')

    # Distribution plot with KDE
    sns.distplot(data, kde=True, color='blue', ax=axes[0])

    # Add lines for mean, median, and mode
    mean_line = axes[0].axvline(data.mean(), color='y', linestyle='--', linewidth=2)
    median_line = axes[0].axvline(data.median(), color='r', linestyle='dashed', linewidth=2)
    mode_line = axes[0].axvline(data.mode()[0], color='g', linestyle='solid', linewidth=2)

    # Create a custom legend
    axes[0].legend([mean_line, median_line, mode_line], ['Mean', 'Median', 'Mode'])

    # Boxplot with means plotted separately
    sns.boxplot(x=data, showmeans=True, orient='h', color="blue", ax=axes[1])

    # Add lines for mean, median, and mode
    mean_line = axes[1].axvline(data.mean(), color='y', linestyle='--', linewidth=2)
    median_line = axes[1].axvline(data.median(), color='r', linestyle='dashed', linewidth=2)
    mode_line = axes[1].axvline(data.mode()[0], color='g', linestyle='solid', linewidth=2)

    # Create a custom legend
    axes[1].legend([mean_line, median_line, mode_line], ['Mean', 'Median', 'Mode'])
    plt.show()

# %%
dist_box(Data.Income)
np.median(Data.Income)
# Out:
# /tmp/ipython-input-159-411673676.py:9: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(data, kde=True, color='blue', ax=axes[0])
# np.float64(50596.5)

# %%
plt.figure(figsize=(14,7))
Data["Product"].value_counts().plot.pie(autopct='%1.1f%%',figsize=(8,8))
plt.title("Product Distribution")
plt.show()
